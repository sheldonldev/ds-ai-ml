# %% [markdown]
# # Link to GitHub

# %% [markdown]
# This notebook will be mainly used for the capstone project

# %% [markdown]
# PROMPT
# Create a new repository on your Github account and name it Coursera_Capstone. I have prepared a guide to walk you through the process of creating a repository and setting it up.
#
# - create a token in github.
# - if token exsists, copy it to platform's account setting
# - link a platform's project to a github repo
# - publish files of this project to the github repo
#
# Now, start a Jupyter Notebook using any platform that you are comfortable with and do the following:
#
# Write some markdown to explain that this notebook will be mainly used for the capstone project.
# Import the pandas library as pd.
# Import the Numpy library as np.
# Print the following the statement: Hello Capstone Project Course!
# Push the Notebook to your Github repository and submit a link to the notebook on your Github repository.
#
# https://github.com/tane-rs/Coursera_Capstone/blob/master/ibm-ds-capston-w2.ipynb

# %%
import pandas as pd
import numpy as np
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
